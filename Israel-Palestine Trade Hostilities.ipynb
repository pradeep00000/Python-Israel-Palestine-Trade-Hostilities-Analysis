# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.head()
# Out:
#   Country Name insrael Country ISO3  Year  \
# 0               Israel          ISR  1960
# 1               Israel          ISR  1960
# 2               Israel          ISR  1960
# 3               Israel          ISR  1960
# 4               Israel          ISR  1960
#
#                                       Indicator Name     Indicator Code  \
# 0                       Trade in services (% of GDP)  BG.GSR.NFSV.GD.ZS
# 1  Communications, computer, etc. (% of service i...     BM.GSR.CMCP.ZS
# 2   Imports of goods and services (BoP, current US$)     BM.GSR.GNFS.CD
# 3  Insurance and financial services (% of service...     BM.GSR.INSF.ZS
# 4                   Goods imports (BoP, current US$)     BM.GSR.MRCH.CD
#
#    Value finaly israel  id Palestine numbers    country iso3  \
# 0  704.226.819.986.843                157834  Palestine  PSE
# 1  266.666.666.666.667                148670  Palestine  PSE
# 2            613000000                     0          0    0
# ...

# %%
df.columns
# Out:
# Index(['Country Name insrael', 'Country ISO3', 'Year', 'Indicator Name',
#        'Indicator Code', 'Value finaly israel', 'id Palestine numbers',
#        'country', 'iso3', 'latitude', 'longitude', 'centroid', 'role',
#        'displacement_type', 'qualifier', 'figure', 'displacement_date',
#        'displacement_start_date', 'displacement_end_date', 'year', 'event_id',
#        'event_name', 'event_start_date', 'event_end_date'],
#       dtype='object')

# %%
df.rename(columns = {'Country Name insrael' : 'Country Name', 'Value finaly israel' : 'Value Finaly'} , inplace = True)

# %%
df.columns
# Out:
# Index(['Country Name', 'Country ISO3', 'Year', 'Indicator Name',
#        'Indicator Code', 'Value Finaly', 'id Palestine numbers', 'country',
#        'iso3', 'latitude', 'longitude', 'centroid', 'role',
#        'displacement_type', 'qualifier', 'figure', 'displacement_date',
#        'displacement_start_date', 'displacement_end_date', 'year', 'event_id',
#        'event_name', 'event_start_date', 'event_end_date'],
#       dtype='object')

# %%
df.describe()
# Out:
#               Year  id Palestine numbers        figure         year  \
# count  5939.000000           5939.000000  5.939000e+03  5939.000000
# mean   1995.587136           3460.745243  1.225129e+03    44.985351
# std      17.452257          22962.878570  3.156448e+04   298.398494
# min    1960.000000              0.000000  0.000000e+00     0.000000
# 25%    1981.000000              0.000000  0.000000e+00     0.000000
# 50%    1999.000000              0.000000  0.000000e+00     0.000000
# 75%    2011.000000              0.000000  0.000000e+00     0.000000
# max    2023.000000         161555.000000  1.335000e+06  2024.000000
#
#            event_id
# count   5939.000000
# mean     549.163327
# std     3654.896706
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max    26733.000000

# %%
sns.boxplot(x = 'Indicator Name' , y = 'Value Finaly' , data = df)
plt.show()
plt.figure(figsize = (9,6))

# %%
sns.pairplot(df)
plt.show()
